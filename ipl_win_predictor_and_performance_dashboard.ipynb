# %%
# Importing libraries for data manipulation
import pandas as pd   
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
match_df = pd.read_csv("matches.csv")   # Reading the matches dataset

# %%
match_df.columns  # Checking columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
delivery_df = pd.read_csv("deliveries.csv") # Reading the deliveries dataset

# %%
delivery_df.columns  # Checking columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
match_df.head() # Display 1st 5 rows of matches dataset
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
delivery_df.head() # Display 1st 5 rows of deliveries dataset
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
df = match_df.merge(delivery_df,left_on = 'id', right_on = 'match_id') # merging the deliveries and matches dataset

# %%
df.head() # Display 1st 5 rows
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 2  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 3  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 4  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner  ...   bowler  non_striker batsman_runs  \
# ...

# %%
df.columns # Checking columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
final_df = df[['id','inning', 'city', 'toss_winner', 'toss_decision', 'winner', 'target_runs', 'target_overs' , 'batting_team', 
       'bowling_team', 'over', 'ball', 'total_runs',
       'player_dismissed']]    # Selecting the required columns

# %%
final_df.head() # Display 1st 5 rows
# Out:
#        id  inning       city                  toss_winner toss_decision  \
# 0  335982       1  Bangalore  Royal Challengers Bangalore         field
# 1  335982       1  Bangalore  Royal Challengers Bangalore         field
# 2  335982       1  Bangalore  Royal Challengers Bangalore         field
# 3  335982       1  Bangalore  Royal Challengers Bangalore         field
# 4  335982       1  Bangalore  Royal Challengers Bangalore         field
#
#                   winner  target_runs  target_overs           batting_team  \
# 0  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
# 1  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
# 2  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
# 3  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
# 4  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
#
#                   bowling_team  over  ball  total_runs player_dismissed
# ...

# %%
final_df['player_dismissed'] = final_df['player_dismissed'].apply(lambda x : 0 if pd.isna(x) else 1)  # Convering the player_dismissed columns to 0 and 1
# Out:
# /var/folders/63/lbh08h3d0hd2phv6kwm5y_lm0000gn/T/ipykernel_37786/642438454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['player_dismissed'] = final_df['player_dismissed'].apply(lambda x : 0 if pd.isna(x) else 1)  # Convering the player_dismissed columns to 0 and 1

# %%
final_df['player_dismissed'].unique() # Checking unique values
# Out:
# array([0, 1])

# %%
final_df.shape # checking the shape of the dataset
# Out:
# (260920, 14)

# %%
final_df['current_run']=final_df.groupby(['inning','id'])['total_runs'].cumsum()  # calculating the current runs
# Out:
# /var/folders/63/lbh08h3d0hd2phv6kwm5y_lm0000gn/T/ipykernel_37786/3636759279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['current_run']=final_df.groupby(['inning','id'])['total_runs'].cumsum()  # calculating the current runs

# %%
final_df['required_run'] = final_df['target_runs'] - final_df['current_run'] # calculating the required runs
# Out:
# /var/folders/63/lbh08h3d0hd2phv6kwm5y_lm0000gn/T/ipykernel_37786/291329973.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['required_run'] = final_df['target_runs'] - final_df['current_run'] # calculating the required runs

# %%
final_df['balls_left'] = 120 - final_df['over']*6 - final_df['ball']  # calculating the balls left
# Out:
# /var/folders/63/lbh08h3d0hd2phv6kwm5y_lm0000gn/T/ipykernel_37786/2644524477.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['balls_left'] = 120 - final_df['over']*6 - final_df['ball']  # calculating the balls left

# %%
final_df['player_down'] = final_df.groupby(['inning','id'])['player_dismissed'].cumsum() # calculating the wickets down
# Out:
# /var/folders/63/lbh08h3d0hd2phv6kwm5y_lm0000gn/T/ipykernel_37786/360295935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['player_down'] = final_df.groupby(['inning','id'])['player_dismissed'].cumsum() # calculating the wickets down

# %%
final_df['wicket_left'] = 10 - final_df['player_down'] # calculating the wickets left
# Out:
# /var/folders/63/lbh08h3d0hd2phv6kwm5y_lm0000gn/T/ipykernel_37786/2461562220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['wicket_left'] = 10 - final_df['player_down'] # calculating the wickets left

# %%
final_df['current_rr'] = (final_df['current_run']*6)/(120-final_df['balls_left'])  # calculating the current run rate
# Out:
# /var/folders/63/lbh08h3d0hd2phv6kwm5y_lm0000gn/T/ipykernel_37786/4259821611.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['current_rr'] = (final_df['current_run']*6)/(120-final_df['balls_left'])  # calculating the current run rate

# %%
final_df['required_rr'] = final_df['required_run']*6/final_df['balls_left'] # calculating the required runs rate
# Out:
# /var/folders/63/lbh08h3d0hd2phv6kwm5y_lm0000gn/T/ipykernel_37786/2768559183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['required_rr'] = final_df['required_run']*6/final_df['balls_left'] # calculating the required runs rate

# %%
final_df.head() # Display 1st 5 rows
# Out:
#        id  inning       city                  toss_winner toss_decision  \
# 0  335982       1  Bangalore  Royal Challengers Bangalore         field
# 1  335982       1  Bangalore  Royal Challengers Bangalore         field
# 2  335982       1  Bangalore  Royal Challengers Bangalore         field
# 3  335982       1  Bangalore  Royal Challengers Bangalore         field
# 4  335982       1  Bangalore  Royal Challengers Bangalore         field
#
#                   winner  target_runs  target_overs           batting_team  \
# 0  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
# 1  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
# 2  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
# 3  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
# 4  Kolkata Knight Riders        223.0          20.0  Kolkata Knight Riders
#
#                   bowling_team  ...  ball  total_runs  player_dismissed  \
# ...

# %%
final_df.columns # Display columns
# Out:
# Index(['id', 'inning', 'city', 'toss_winner', 'toss_decision', 'winner',
#        'target_runs', 'target_overs', 'batting_team', 'bowling_team', 'over',
#        'ball', 'total_runs', 'player_dismissed', 'current_run', 'required_run',
#        'balls_left', 'player_down', 'wicket_left', 'current_rr',
#        'required_rr'],
#       dtype='object')

# %%
final_df.shape # checking the shape of dataset
# Out:
# (260920, 21)

# %%
final_df = final_df[(final_df['inning'].isin([1,2]))] # Filtering the dataset for only 1st and 2nd innings

# %%
final_df.shape  # checking the shape of dataset
# Out:
# (260759, 21)

# %%
inn_2 = final_df[final_df['inning'] == 2]  # Filtering the dataset for only 2nd innings

# %%
inn_2.shape  # checking the shape of dataset
# Out:
# (125741, 21)

# %%
inn_2.head() # Display 1st 5 rows
# Out:
#          id  inning       city                  toss_winner toss_decision  \
# 124  335982       2  Bangalore  Royal Challengers Bangalore         field
# 125  335982       2  Bangalore  Royal Challengers Bangalore         field
# 126  335982       2  Bangalore  Royal Challengers Bangalore         field
# 127  335982       2  Bangalore  Royal Challengers Bangalore         field
# 128  335982       2  Bangalore  Royal Challengers Bangalore         field
#
#                     winner  target_runs  target_overs  \
# 124  Kolkata Knight Riders        223.0          20.0
# 125  Kolkata Knight Riders        223.0          20.0
# 126  Kolkata Knight Riders        223.0          20.0
# 127  Kolkata Knight Riders        223.0          20.0
# 128  Kolkata Knight Riders        223.0          20.0
#
#                     batting_team           bowling_team  ...  ball  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders  ...     1
# ...

# %%
def result(row):  # Function to determine if the batting team won or not
    return 1 if row['winner'] == row['batting_team'] else 0

# %%
inn_2['result'] = inn_2.apply(result,axis = 1) # Applying the result function to the dataset
# Out:
# /var/folders/63/lbh08h3d0hd2phv6kwm5y_lm0000gn/T/ipykernel_37786/2277691269.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inn_2['result'] = inn_2.apply(result,axis = 1) # Applying the result function to the dataset

# %%
inn_2.head()
# Out:
#          id  inning       city                  toss_winner toss_decision  \
# 124  335982       2  Bangalore  Royal Challengers Bangalore         field
# 125  335982       2  Bangalore  Royal Challengers Bangalore         field
# 126  335982       2  Bangalore  Royal Challengers Bangalore         field
# 127  335982       2  Bangalore  Royal Challengers Bangalore         field
# 128  335982       2  Bangalore  Royal Challengers Bangalore         field
#
#                     winner  target_runs  target_overs  \
# 124  Kolkata Knight Riders        223.0          20.0
# 125  Kolkata Knight Riders        223.0          20.0
# 126  Kolkata Knight Riders        223.0          20.0
# 127  Kolkata Knight Riders        223.0          20.0
# 128  Kolkata Knight Riders        223.0          20.0
#
#                     batting_team           bowling_team  ...  total_runs  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders  ...           1
# ...

# %%
inn_2.columns # checking the columns
# Out:
# Index(['id', 'inning', 'city', 'toss_winner', 'toss_decision', 'winner',
#        'target_runs', 'target_overs', 'batting_team', 'bowling_team', 'over',
#        'ball', 'total_runs', 'player_dismissed', 'current_run', 'required_run',
#        'balls_left', 'player_down', 'wicket_left', 'current_rr', 'required_rr',
#        'result'],
#       dtype='object')

# %%
final_data = inn_2[['batting_team','bowling_team','city','target_runs','required_run','balls_left','wicket_left','current_rr','required_rr','result']]

# %%
final_data.head()
# Out:
#                     batting_team           bowling_team       city  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#      target_runs  required_run  balls_left  wicket_left  current_rr  \
# 124        223.0         222.0         119           10         6.0
# 125        223.0         221.0         118           10         6.0
# 126        223.0         221.0         117           10         4.0
# 127        223.0         220.0         116           10         4.5
# 128        223.0         219.0         115           10         4.8
#
#      required_rr  result
# 124    11.193277       0
# 125    11.237288       0
# 126    11.333333       0
# 127    11.379310       0
# ...

# %%
final_data = final_data[~final_data['batting_team'].isin(['Kochi Tuskers Kerala','Pune Warriors','Gujarat Lions','Rising Pune Supergiants','Rising Pune Supergiant'])
& ~final_data['bowling_team'].isin(['Kochi Tuskers Kerala','Pune Warriors','Gujarat Lions','Rising Pune Supergiants','Rising Pune Supergiant'])]

                       # Removing the teams which are no longer the part of IPL

# %%
final_data.shape
# Out:
# (112805, 10)

# %%
final_data.replace(to_replace = 'Royal Challengers Bangalore', value = 'Royal Challengers Bengaluru',inplace = True)
final_data.replace(to_replace = 'Kings XI Punjab', value = 'Punjab Kings',inplace = True)
final_data.replace(to_replace = 'Delhi Daredevils', value = 'Delhi Capitals',inplace = True)
final_data.replace(to_replace = 'Deccan Chargers', value = 'Sunrisers Hyderabad',inplace = True)
     
# Replacing the old team names with new team names

# %%
final_data = final_data.sample(final_data.shape[0]) # shuffling the dataset

# %%
final_data.head() # Display 1st 5 rows
# Out:
#                        batting_team                 bowling_team        city  \
# 154140          Sunrisers Hyderabad                 Punjab Kings  Chandigarh
# 131684                 Punjab Kings  Royal Challengers Bengaluru  Chandigarh
# 37263           Sunrisers Hyderabad          Chennai Super Kings      Nagpur
# 64441   Royal Challengers Bengaluru                 Punjab Kings  Chandigarh
# 145790               Delhi Capitals          Sunrisers Hyderabad       Delhi
#
#         target_runs  required_run  balls_left  wicket_left  current_rr  \
# 154140        194.0         152.0          82            7    6.631579
# 131684        176.0         111.0          72            9    8.125000
# 37263         139.0          78.0          56            8    5.718750
# 64441         164.0          93.0          62            7    7.344828
# 145790        186.0          77.0          50            7    9.342857
#
#         required_rr  result
# 154140    11.121951       0
# ...

# %%
final_data.isnull().sum() # checking for null values
# Out:
# batting_team       0
# bowling_team       0
# city            6012
# target_runs        0
# required_run       0
# balls_left         0
# wicket_left        0
# current_rr         0
# required_rr       16
# result             0
# dtype: int64

# %%
final_data.dropna(inplace=True) # removing null values

# %%
final_data = final_data[final_data['balls_left']!=0] # removing the rows where balls left is 0 (it makes infinite values in required_rr)

# %%
final_data.info() # checking the info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 106427 entries, 154140 to 161382
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   batting_team  106427 non-null  object
#  1   bowling_team  106427 non-null  object
#  2   city          106427 non-null  object
#  3   target_runs   106427 non-null  float64
#  4   required_run  106427 non-null  float64
#  5   balls_left    106427 non-null  int64
#  6   wicket_left   106427 non-null  int64
#  7   current_rr    106427 non-null  float64
#  8   required_rr   106427 non-null  float64
#  9   result        106427 non-null  int64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 8.9+ MB

# %%
final_data.describe() # checking the statistical measures of the dataset
# Out:
#          target_runs   required_run     balls_left    wicket_left  \
# count  106427.000000  106427.000000  106427.000000  106427.000000
# mean      169.144935      94.511524      62.950078       7.517209
# std        31.475622      51.024426      33.302916       2.153557
# min        43.000000     -10.000000      -3.000000       0.000000
# 25%       149.000000      54.000000      35.000000       6.000000
# 50%       169.000000      93.000000      64.000000       8.000000
# 75%       189.000000     132.000000      92.000000       9.000000
# max       288.000000     287.000000     119.000000      10.000000
#
#           current_rr    required_rr         result
# count  106427.000000  106427.000000  106427.000000
# mean        7.628711      10.674642       0.517049
# std         2.377280      14.133668       0.499712
# min         0.000000    -516.000000       0.000000
# 25%         6.409091       7.304348       0.000000
# 50%         7.636364       9.057692       1.000000
# ...

# %%
final_data.shape # checking the shape of dataset
# Out:
# (106427, 10)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
 
             # Importing libraries for model building and evaluation

# %%
x = final_data.drop(columns=['result']) # independent features
y = final_data['result'] # dependent features

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=5) # splitting the dataset into training and testing set

# %%
trf = ColumnTransformer([  
    ('ohe',OneHotEncoder(sparse_output=False, drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')  # Column transformer for one hot encoding the categorical features

# %%
pipe = Pipeline(steps = [
    ('step1',trf),
    ('step2',LogisticRegression(solver = 'liblinear') )
])                                                        # Creating a pipeline for the model

# %%
pipe.fit(x_train,y_train) # fitting the model
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(x_test) # predicting the values

# %%
accuracy_score(y_test,y_pred) # checking the accuracy of the model
# Out:
# 0.8026872122521845

# %%
sample = pd.DataFrame([{
    'batting_team': 'Delhi Capitals',
    'bowling_team': 'Royal Challengers Bengaluru',
    'city': 'Bengaluru',
    'target_runs': 150.0,
    'required_run': 97.0,
    'balls_left': 86,
    'wicket_left': 9,
    'current_rr': 9.352941,
    'required_rr': 6.767442
}])

# %%
print(pipe.predict_proba(sample))
# Out:
# [[0.1020502 0.8979498]]

# %%
import pickle 
pickle.dump(pipe,open('pipe.pkl','wb'))  # saving the model to the local system
